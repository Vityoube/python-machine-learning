# %%
import matplotlib.pyplot as plt

names = ["Decision Tree", "KNN", "Logistic Reg"]
scores = [0.917, 0.944, 1.000]

# write code below this line
plt.bar(names, scores)
plt.ylabel("Accuracy")
plt.title("Wine Classifiers")
plt.ylim(0, 1.1)
plt.show()
